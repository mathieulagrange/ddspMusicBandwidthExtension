# %%
import matplotlib.pyplot as plt
from IPython.display import Audio
import os
from scipy.io.wavfile import read

model = 'ddsp_BWE_genericLoudness'
audio_path = f'/home/user/python/modibe/models/{model}/audio/'

fs = 16000

# %%
filename = 'Tbn-ord-F#4-pp-N-T10u'
n_steps = 10000
Audio(filename = f'{audio_path}{filename}_regen_{n_steps}.wav', autoplay=True)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
